# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import numpy as np

# %%
# !ls "UN Food Waste Index.xlsx"
# Out:
# UN Food Waste Index.xlsx

# %%
df = pd.read_csv("UN FOOD WASTE.csv")

# %%
df.head(10)
# Out:
#    Study_#                                             Source  \
# 0        1  National Food Waste Baseline: Final assessment...
# 1        1  National Food Waste Baseline: Final assessment...
# 2        1  National Food Waste Baseline: Final assessment...
# 3        2                      Food Waste Statistics Austria
# 4        2                      Food Waste Statistics Austria
# 5        2                      Food Waste Statistics Austria
# 6        3  Review of studies on food waste accounting at ...
# 7        3  Review of studies on food waste accounting at ...
# 8        3  Review of studies on food waste accounting at ...
# 9        3  Review of studies on food waste accounting at ...
#
#    Publication_year                                               Link  \
# 0              2019  http://www.environment.gov.au/system/files/pag...
# 1              2019  http://www.environment.gov.au/system/files/pag...
# 2              2019  http://www.environment.gov.au/system/files/pag...
# 3              2017  https://ec.europa.eu/food/sites/food/files/saf...
# 4              2017  https://ec.europa.eu/food/sites/food/files/saf...
# 5              2017  https://ec.europa.eu/food/sites/food/files/saf...
# 6              2019  https://op.europa.eu/en/publication-detail/-/p...
# 7              2019  https://op.europa.eu/en/publication-detail/-/p...
# 8              2019  https://op.europa.eu/en/publication-detail/-/p...
# 9              2019  https://op.europa.eu/en/publication-detail/-/p...
#
#       Country  M49_Code                     Region   Category  \
# 0   Australia        36  Australia and New Zealand  Developed
# 1   Australia        36  Australia and New Zealand  Developed
# 2   Australia        36  Australia and New Zealand  Developed
# 3     Austria        40             Western Europe  Developed
# 4     Austria        40             Western Europe  Developed
# 5     Austria        40             Western Europe  Developed
# 6     Austria        40             Western Europe  Developed
# 7     Estonia       233            Northern Europe  Developed
# 8  Luxembourg       442             Western Europe  Developed
# 9  Luxembourg       442             Western Europe  Developed
#
#   WB_Income_Category Study_area_level  ... Normalised_Weight_Adjustment_kg  \
# 0                HIC       Nationwide  ...                             NaN
# 1                HIC       Nationwide  ...                             NaN
# 2                HIC       Nationwide  ...                             NaN
# 3                HIC       Nationwide  ...                             NaN
# 4                HIC       Nationwide  ...                            39.0
# 5                HIC       Nationwide  ...                             NaN
# 6                HIC       Nationwide  ...                             NaN
# 7                HIC       Nationwide  ...                             NaN
# 8                HIC       Nationwide  ...                             9.0
# 9                HIC       Nationwide  ...                            90.0
#
#    Normalised_Time_Adjustment_Y  Standardised_Normalised_Mass_kg/capita/year  \
# 0                           NaN                                          NaN
# 1                           NaN                                          NaN
# 2                           NaN                                          NaN
# 3                           NaN                                          NaN
# 4                          39.0                                         39.0
# 5                           NaN                                          NaN
# 6                           NaN                                          NaN
# 7                           NaN                                          NaN
# 8                           9.0                                          9.0
# 9                          90.0                                         90.0
#
#    Preferred_estimate_kg/capita  Household_Diary_Adjustment  \
# 0                           102                         1.0
# 1                            22                         1.0
# 2                             9                         1.0
# 3                            26                         1.0
# 4                            39                         1.0
# 5                             9                         1.0
# 6                            31                         1.0
# 7                             5                         1.0
# 8                             9                         1.0
# 9                            90                         1.0
#
#   Household_Inedible_Adjustment  Food_Service_Inedible_Adjustment  \
# 0                           1.0                               1.0
# 1                           1.0                               1.0
# 2                           1.0                               1.0
# 3                           1.0                               1.0
# 4                           1.0                               1.0
# 5                           1.0                               1.0
# 6                           1.0                               1.0
# 7                           1.0                               1.0
# 8                           1.0                               1.0
# 9                           1.0                               1.0
#
#   Retail_Inedible_Adjustment  Total_Adjustment  Final_kg/cap/yr_estimate
# 0                        1.0               1.0                       102
# 1                        1.0               1.0                        22
# 2                        1.0               1.0                         9
# 3                        1.0               1.0                        26
# 4                        1.0               1.0                        39
# 5                        1.0               1.0                         9
# 6                        1.0               1.0                        31
# 7                        1.0               1.0                         5
# 8                        1.0               1.0                         9
# 9                        1.0               1.0                        90
#
# [10 rows x 46 columns]

# %%
def find_country(row):
    for i in range(len(row)):
         print(row[i])
        if "(" in str(row[i]) or "ie" in str(row[i]):
#             print("here")
            row[i] = 0.0
        else:
#             print(row[i])
            row[i] = float(row[i])
            
#     print("here")
    return row
# Out:
#   File "<tokenize>", line 4
#     if "(" in str(row[i]) or "ie" in str(row[i]):
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
Biomass_df = Biomass_df.apply(lambda row: find_non_ints(row), axis=1)
Biomass_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cf/zgwyjvw96f95sg48n3g4x48m0000gn/T/ipykernel_46466/3749721856.py in <module>
# ----> 1 Biomass_df = Biomass_df.apply(lambda row: find_non_ints(row), axis=1)
#       2 Biomass_df
#
# NameError: name 'Biomass_df' is not defined
